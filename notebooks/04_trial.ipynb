# %%
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
client = mlflow.MlflowClient()
models = client.search_registered_models()
print([m.name for m in models])
# Out:
# ['aml-shield-xgboost']

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/fripuran/aml-shield-main/notebooks'
